# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv(".env")
# Out:
# False

# %%
os.environ['SAMPLE_VAR']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 os.environ['SAMPLE_VAR']
#
# File <frozen os>:714, in __getitem__(self, key)
#
# KeyError: 'SAMPLE_VAR'
